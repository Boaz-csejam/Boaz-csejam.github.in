# %% [markdown]
# <a href="https://colab.research.google.com/github/Boaz-csejam/Boaz-csejam.github.in/blob/master/seabornpython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

# %%
df=sns.load_dataset("tips")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# COREERLATION HEATMAP
#
# IT IS A FEATURE SELECTION AND BASICALLY SHOWS A 2 D CORRELATION MATRIX BETWEEN THE TWO DISCRETE DIMENSIONS OR EVENT TYPES

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
sns.heatmap(df.corr())

# %% [markdown]
# basically for feature engineering

# %% [markdown]
# joint plot used to do univarient /bivarent

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='hex')

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='reg')

# %% [markdown]
# hex--- the structures in the mid will be seen in the hexagonal way
#
# reg it gives a regression line

# %% [markdown]
# pair plot is also known as the scatter plot where one data in the same variable is matched with the other variable's value

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='sex')

# %%
sns.pairplot(df,hue='smoker')

# %%
df['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %% [markdown]
# dist plot
#
#
# creating histograms

# %%
sns.distplot(df['tip'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['size'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.displot(df['tip'],kde=False,bins=10)

# %% [markdown]
# A kernel density estimate (KDE) plot is a method for visualizing the distribution of observations in a dataset, analagous to a histogram. KDE represents the data using a continuous probability density curve in one or more dimensions.
#
#
#
# A histogram displays numerical data by grouping data into "bins" of equal width. Each bin is plotted as a bar whose height corresponds to how many data points are in that bin. Bins are also sometimes called "intervals", "classes", or "buckets"

# %% [markdown]
# NOW CATAGORICAL **PLOTS**

# %% [markdown]
# COUNT PLOT Shows each counts of observation in each catagorical bin using bars

# %%
sns.countplot('sex',data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot('day',data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot('smoker',data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(y='sex',data=df)

# %% [markdown]
# barplot need to say x and y column

# %%
sns.barplot(y='total_bill',x="smoker",data=df)

# %% [markdown]
# box plot describes information from a five number summary

# %%
sns.barplot('sex','total_bill',data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(x='day',y='total_bill',data=df)

# %% [markdown]
# violin plot descriibes data in the form of kde and boxplot

# %%
sns.violinplot(x='total_bill',y='day',data=df,palette='rainbow')
